# %%
from rocqiomics import Rocqiomics
from rocqiomics.personal_utils import prepare_data_dicts

from monai.transforms import (
    Compose,
    ScaleIntensityd,
    NormalizeIntensityd,
    Spacingd,
)

BASEPATH = r'O:\Ricardo\Imaging Datasets\Imaging\Preclinical\Phantom\Snickers Repeatability\NRRD Files'

# %% [markdown]
# # Prepare `data_dicts`

# %% [markdown]
# `data_dicts` is the main input to the pipeline, and should minimally contain `image` and `mask` keywords for each case.
# Additional metadata such as timepoint, modality, etc can be added via the `metadata` keyword.

# %%
# Custom function that generates data dicts from my usual folder structure.
# You don't need to use this, of course, as long as you generate the data_dicts with the required structure.
data_dicts = prepare_data_dicts(
    base_dirpath=BASEPATH,
    mask_names=['Snickers_Ricardo'],
    modalities=['T2'],
    timepoints=['d1', 'd5', 'd8'],
)

data_dicts[0]
# Out:
# {'case_id': 'RGS021425_ph1',
#  'image': 'O:\\Ricardo\\Imaging Datasets\\Imaging\\Preclinical\\Phantom\\Snickers Repeatability\\NRRD Files\\Images\\d1_T2_RGS021425_ph1.nrrd',
#  'mask': 'O:\\Ricardo\\Imaging Datasets\\Imaging\\Preclinical\\Phantom\\Snickers Repeatability\\NRRD Files\\Masks\\Snickers_Ricardo\\d1_T2_RGS021425_ph1.seg.nrrd',
#  'metadata': {'mask_name': 'Snickers_Ricardo',
#   'timepoint': 'd1',
#   'modality': 'T2'}}

# %% [markdown]
# # Run the pipeline

# %%
pipeline = Rocqiomics(
    data_dicts=data_dicts,
    preprocessing=Compose([
        NormalizeIntensityd(keys=['image']), # Standardize image intensity (subtract mean and divide by standard dev)
        ScaleIntensityd(keys=['image'], factor=99.0, minv=None, maxv=None), # Scale images by factor of 100 (99 + 1)
        Spacingd(keys=['image', 'mask'], pixdim=(0.125, 0.125, 1.0), mode=[3, 'nearest']), # Resample image and mask to specified voxel size
    ]),
    bin_width=1.0,
    save_results=True,
    save_dirpath=r'tutorial_results',
    save_by_columns=['mask_name', 'modality', 'timepoint'], # Save results in different files based on mask name, modality, and timepoint
)
pipeline.run_pipeline()
results = pipeline.get_results()
# Out:
# Rocqiomics INFO:	 Validating images and masks...
# Rocqiomics INFO:	 Pipeline Initialized | Cases: 44 | Excluded cases: 0
# Rocqiomics INFO:	 Case 0/43 done in 15.41s	case_id: RGS021425_ph1	mask_name: Snickers_Ricardo	timepoint: d1	modality: T2	augmentation: aug_0
# Rocqiomics INFO:	 Case 1/43 done in 14.81s	case_id: RGS021425_ph1	mask_name: Snickers_Ricardo	timepoint: d5	modality: T2	augmentation: aug_0
# Rocqiomics INFO:	 Case 2/43 done in 19.13s	case_id: RGS021425_ph1	mask_name: Snickers_Ricardo	timepoint: d8	modality: T2	augmentation: aug_0
# Rocqiomics INFO:	 Case 3/43 done in 24.93s	case_id: RGS021425_ph2	mask_name: Snickers_Ricardo	timepoint: d1	modality: T2	augmentation: aug_0
# Rocqiomics INFO:	 Case 4/43 done in 26.24s	case_id: RGS021425_ph2	mask_name: Snickers_Ricardo	timepoint: d5	modality: T2	augmentation: aug_0
# Rocqiomics INFO:	 Case 5/43 done in 25.61s	case_id: RGS021425_ph2	mask_name: Snickers_Ricardo	timepoint: d8	modality: T2	augmentation: aug_0
# Rocqiomics INFO:	 Case 6/43 done in 20.47s	case_id: RGS021425_ph3	mask_name: Snickers_Ricardo	timepoint: d1	modality: T2	augmentation: aug_0
# Rocqiomics INFO:	 Case 7/43 done in 17.65s	case_id: RGS021425_ph3	mask_name: Snickers_Ricardo	timepoint: d5	modality: T2	augmentation: aug_0
# Rocqiomics INFO:	 Case 8/43 done in 17.23s	case_id: RGS021425_ph3	mask_name: Snickers_Ricardo	timepoint: d8	modality: T2	augmentation: aug_0
# Rocqiomics INFO:	 Case 9/43 done in 15.07s	case_id: RGS021425_ph4	mask_name: Snickers_Ricardo	timepoint: d1	modality: T2	augmentation: aug_0
# Rocqiomics INFO:	 Case 10/43 done in 15.12s	case_id: RGS021425_ph4	mask_name: Snickers_Ricardo	timepoint: d5	modality: T2	augmentation: aug_0
# Rocqiomics INFO:	 Case 11/43 done in 14.90s	case_id: RGS021425_ph4	mask_name: Snickers_Ricardo	timepoint: d8	modality: T2	augmentation: aug_0
# Rocqiomics INFO:	 Case 12/43 done in 16.31s	case_id: RGS021425_ph5	mask_name: Snickers_Ricardo	timepoint: d1	modality: T2	augmentation: aug_0
# Rocqiomics INFO:	 Case 13/43 done in 16.34s	case_id: RGS021425_ph5	mask_name: Snickers_Ricardo	timepoint: d5	modality: T2	augmentation: aug_0
# Rocqiomics INFO:	 Case 14/43 done in 17.12s	case_id: RGS021425_ph5	mask_name: Snickers_Ricardo	timepoint: d8	modality: T2	augmentation: aug_0
# Rocqiomics INFO:	 Case 15/43 done in 16.38s	case_id: RGS021425_ph6	mask_name: Snickers_Ricardo	timepoint: d1	modality: T2	augmentation: aug_0
# Rocqiomics INFO:	 Case 16/43 done in 13.91s	case_id: RGS021425_ph6	mask_name: Snickers_Ricardo	timepoint: d5	modality: T2	augmentation: aug_0
# Rocqiomics INFO:	 Case 17/43 done in 12.70s	case_id: RGS021425_ph6	mask_name: Snickers_Ricardo	timepoint: d8	modality: T2	augmentation: aug_0
# Rocqiomics INFO:	 Case 18/43 done in 16.29s	case_id: RGS021425_ph7	mask_name: Snickers_Ricardo	timepoint: d5	modality: T2	augmentation: aug_0
# Rocqiomics INFO:	 Case 19/43 done in 18.78s	case_id: RGS021425_ph7	mask_name: Snickers_Ricardo	timepoint: d8	modality: T2	augmentation: aug_0
# Rocqiomics INFO:	 Case 20/43 done in 34.31s	case_id: RGS021425_ph8	mask_name: Snickers_Ricardo	timepoint: d1	modality: T2	augmentation: aug_0
# Rocqiomics INFO:	 Case 21/43 done in 40.57s	case_id: RGS021425_ph8	mask_name: Snickers_Ricardo	timepoint: d5	modality: T2	augmentation: aug_0
# Rocqiomics INFO:	 Case 22/43 done in 35.65s	case_id: RGS021425_ph8	mask_name: Snickers_Ricardo	timepoint: d8	modality: T2	augmentation: aug_0
# Rocqiomics INFO:	 Case 23/43 done in 51.93s	case_id: RGS021425_ph9	mask_name: Snickers_Ricardo	timepoint: d1	modality: T2	augmentation: aug_0
# Rocqiomics INFO:	 Case 24/43 done in 35.79s	case_id: RGS021425_ph9	mask_name: Snickers_Ricardo	timepoint: d5	modality: T2	augmentation: aug_0
# Rocqiomics INFO:	 Case 25/43 done in 38.82s	case_id: RGS021425_ph9	mask_name: Snickers_Ricardo	timepoint: d8	modality: T2	augmentation: aug_0
# Rocqiomics INFO:	 Case 26/43 done in 37.36s	case_id: RGS021425_ph10	mask_name: Snickers_Ricardo	timepoint: d1	modality: T2	augmentation: aug_0
# Rocqiomics INFO:	 Case 27/43 done in 26.76s	case_id: RGS021425_ph10	mask_name: Snickers_Ricardo	timepoint: d5	modality: T2	augmentation: aug_0
# Rocqiomics INFO:	 Case 28/43 done in 33.30s	case_id: RGS021425_ph10	mask_name: Snickers_Ricardo	timepoint: d8	modality: T2	augmentation: aug_0
# Rocqiomics INFO:	 Case 29/43 done in 35.41s	case_id: RGS021425_ph11	mask_name: Snickers_Ricardo	timepoint: d1	modality: T2	augmentation: aug_0
# Rocqiomics INFO:	 Case 30/43 done in 46.24s	case_id: RGS021425_ph11	mask_name: Snickers_Ricardo	timepoint: d5	modality: T2	augmentation: aug_0
# Rocqiomics INFO:	 Case 31/43 done in 45.63s	case_id: RGS021425_ph11	mask_name: Snickers_Ricardo	timepoint: d8	modality: T2	augmentation: aug_0
# Rocqiomics INFO:	 Case 32/43 done in 37.27s	case_id: RGS021425_ph12	mask_name: Snickers_Ricardo	timepoint: d1	modality: T2	augmentation: aug_0
# Rocqiomics INFO:	 Case 33/43 done in 37.16s	case_id: RGS021425_ph12	mask_name: Snickers_Ricardo	timepoint: d5	modality: T2	augmentation: aug_0
# Rocqiomics INFO:	 Case 34/43 done in 35.42s	case_id: RGS021425_ph12	mask_name: Snickers_Ricardo	timepoint: d8	modality: T2	augmentation: aug_0
# Rocqiomics INFO:	 Case 35/43 done in 31.69s	case_id: RGS021425_ph13	mask_name: Snickers_Ricardo	timepoint: d1	modality: T2	augmentation: aug_0
# Rocqiomics INFO:	 Case 36/43 done in 33.86s	case_id: RGS021425_ph13	mask_name: Snickers_Ricardo	timepoint: d5	modality: T2	augmentation: aug_0
# Rocqiomics INFO:	 Case 37/43 done in 35.08s	case_id: RGS021425_ph13	mask_name: Snickers_Ricardo	timepoint: d8	modality: T2	augmentation: aug_0
# Rocqiomics INFO:	 Case 38/43 done in 32.23s	case_id: RGS021425_ph14	mask_name: Snickers_Ricardo	timepoint: d1	modality: T2	augmentation: aug_0
# Rocqiomics INFO:	 Case 39/43 done in 33.07s	case_id: RGS021425_ph14	mask_name: Snickers_Ricardo	timepoint: d5	modality: T2	augmentation: aug_0
# Rocqiomics INFO:	 Case 40/43 done in 34.37s	case_id: RGS021425_ph14	mask_name: Snickers_Ricardo	timepoint: d8	modality: T2	augmentation: aug_0
# Rocqiomics INFO:	 Case 41/43 done in 32.22s	case_id: RGS021425_ph15	mask_name: Snickers_Ricardo	timepoint: d1	modality: T2	augmentation: aug_0
# Rocqiomics INFO:	 Case 42/43 done in 32.85s	case_id: RGS021425_ph15	mask_name: Snickers_Ricardo	timepoint: d5	modality: T2	augmentation: aug_0
# Rocqiomics INFO:	 Case 43/43 done in 36.51s	case_id: RGS021425_ph15	mask_name: Snickers_Ricardo	timepoint: d8	modality: T2	augmentation: aug_0
# Rocqiomics INFO:	 Results saved to tutorial_results\d1_T2_Snickers_Ricardo.xlsx
# Rocqiomics INFO:	 Results saved to tutorial_results\d5_T2_Snickers_Ricardo.xlsx
# Rocqiomics INFO:	 Results saved to tutorial_results\d8_T2_Snickers_Ricardo.xlsx

# %%
results.head(6)
# Out:
#               diagnostics_Versions_PyRadiomics diagnostics_Versions_Numpy  \
# case_id
# RGS021425_ph1                           v3.1.0                     1.26.4
# RGS021425_ph1                           v3.1.0                     1.26.4
# RGS021425_ph1                           v3.1.0                     1.26.4
# RGS021425_ph2                           v3.1.0                     1.26.4
# RGS021425_ph2                           v3.1.0                     1.26.4
# RGS021425_ph2                           v3.1.0                     1.26.4
#
#               diagnostics_Versions_SimpleITK diagnostics_Versions_PyWavelet  \
# case_id
# RGS021425_ph1                          2.4.0                          1.6.0
# RGS021425_ph1                          2.4.0                          1.6.0
# RGS021425_ph1                          2.4.0                          1.6.0
# RGS021425_ph2                          2.4.0                          1.6.0
# RGS021425_ph2                          2.4.0                          1.6.0
# RGS021425_ph2                          2.4.0                          1.6.0
#
#               diagnostics_Versions_Python  \
# case_id
# RGS021425_ph1                      3.9.21
# RGS021425_ph1                      3.9.21
# RGS021425_ph1                      3.9.21
# RGS021425_ph2                      3.9.21
# RGS021425_ph2                      3.9.21
# RGS021425_ph2                      3.9.21
#
#                               diagnostics_Configuration_Settings  \
# case_id
# RGS021425_ph1  {'minimumROIDimensions': 2, 'minimumROISize': ...
# RGS021425_ph1  {'minimumROIDimensions': 2, 'minimumROISize': ...
# RGS021425_ph1  {'minimumROIDimensions': 2, 'minimumROISize': ...
# RGS021425_ph2  {'minimumROIDimensions': 2, 'minimumROISize': ...
# RGS021425_ph2  {'minimumROIDimensions': 2, 'minimumROISize': ...
# RGS021425_ph2  {'minimumROIDimensions': 2, 'minimumROISize': ...
#
#               diagnostics_Configuration_EnabledImageTypes  \
# case_id
# RGS021425_ph1                            {'Original': {}}
# RGS021425_ph1                            {'Original': {}}
# RGS021425_ph1                            {'Original': {}}
# RGS021425_ph2                            {'Original': {}}
# RGS021425_ph2                            {'Original': {}}
# RGS021425_ph2                            {'Original': {}}
#
#                         diagnostics_Image-original_Hash  \
# case_id
# RGS021425_ph1  d2905c171f37ce8240e980e773329736370e5007
# RGS021425_ph1  b6d94670ce37947214ecb9736a64db67632dbbdf
# RGS021425_ph1  e9870564040885b755a8bf6922465f32991ac121
# RGS021425_ph2  48b0c766c658a0aca4818bf1b5ca16e8d152bfad
# RGS021425_ph2  d3797548b6a8d2e6c24be408bda24e25db1624d8
# RGS021425_ph2  ecfdeff7c16e405c753cc6b7bd701f27c2d1ad3c
#
#               diagnostics_Image-original_Dimensionality  \
# case_id
# RGS021425_ph1                                        3D
# RGS021425_ph1                                        3D
# RGS021425_ph1                                        3D
# RGS021425_ph2                                        3D
# RGS021425_ph2                                        3D
# RGS021425_ph2                                        3D
#
#               diagnostics_Image-original_Spacing  ...  \
# case_id                                           ...
# RGS021425_ph1                (0.125, 0.125, 1.0)  ...
# RGS021425_ph1                (0.125, 0.125, 1.0)  ...
# RGS021425_ph1                (0.125, 0.125, 1.0)  ...
# RGS021425_ph2                (0.125, 0.125, 1.0)  ...
# RGS021425_ph2                (0.125, 0.125, 1.0)  ...
# RGS021425_ph2                (0.125, 0.125, 1.0)  ...
#
#               original_glszm_ZoneVariance  original_ngtdm_Busyness  \
# case_id
# RGS021425_ph1          0.8765786307573585       0.4125578634174827
# RGS021425_ph1          1.3192624322964552       0.4820629754285023
# RGS021425_ph1          0.7756665388513606      0.43099893452577204
# RGS021425_ph2          0.5830860708134699       0.3545718286188622
# RGS021425_ph2          0.5958467501197663       0.3735152579879551
# RGS021425_ph2          0.7144124005658443       0.4407951218779428
#
#                original_ngtdm_Coarseness  original_ngtdm_Complexity  \
# case_id
# RGS021425_ph1     5.1647857779674305e-05          1992683.767318892
# RGS021425_ph1      5.016845533321195e-05         1635354.4080022278
# RGS021425_ph1      4.959691836708339e-05         2141599.9255982256
# RGS021425_ph2      5.220102780391982e-05          2439394.162054831
# RGS021425_ph2     5.2461080300582086e-05          2371904.967535181
# RGS021425_ph2      5.125013638669757e-05         1878293.9933540786
#
#               original_ngtdm_Contrast original_ngtdm_Strength  \
# case_id
# RGS021425_ph1      2.1151550054237545       7.503518344451568
# RGS021425_ph1      1.8835265507524068       6.741934991549189
# RGS021425_ph1      2.0718265111103076       7.765940313587438
# RGS021425_ph2      1.9107966450794576       8.150952533574173
# RGS021425_ph2       1.891853545784056       8.105515011082923
# RGS021425_ph2       1.812771934071533       6.947552972367335
#
#                       mask_name timepoint  modality  augmentation
# case_id
# RGS021425_ph1  Snickers_Ricardo        d1        T2         aug_0
# RGS021425_ph1  Snickers_Ricardo        d5        T2         aug_0
# RGS021425_ph1  Snickers_Ricardo        d8        T2         aug_0
# RGS021425_ph2  Snickers_Ricardo        d1        T2         aug_0
# RGS021425_ph2  Snickers_Ricardo        d5        T2         aug_0
# RGS021425_ph2  Snickers_Ricardo        d8        T2         aug_0
#
# [6 rows x 133 columns]

# %% [markdown]
# # Load the saved features and compute the longitudinal COV

# %%
from rocqiomics.personal_utils import load_feature_sets, get_longitudinal_cov

# Custom function that loads saved feature sets according to my usual file structure.
# Again, you can use your own loading logic
df = load_feature_sets(
    features_dirpath=r"tutorial_results",
    mask_names=['Snickers_Ricardo']
)

df
# Out:
#                 original_shape_Elongation  original_shape_Flatness  \
# case_id
# RGS021425_ph1                    0.620299                 0.423788
# RGS021425_ph2                    0.607777                 0.432801
# RGS021425_ph3                    0.561831                 0.421890
# RGS021425_ph4                    0.624125                 0.430350
# RGS021425_ph5                    0.604602                 0.433641
# RGS021425_ph6                    0.642383                 0.444427
# RGS021425_ph8                    0.581190                 0.427515
# RGS021425_ph9                    0.570693                 0.427902
# RGS021425_ph10                   0.584541                 0.431278
# RGS021425_ph11                   0.555612                 0.422500
# RGS021425_ph12                   0.582617                 0.422374
# RGS021425_ph13                   0.609386                 0.439371
# RGS021425_ph14                   0.603627                 0.440424
# RGS021425_ph15                   0.623868                 0.428520
# RGS021425_ph1                    0.622125                 0.425055
# RGS021425_ph2                    0.606498                 0.432048
# RGS021425_ph3                    0.562362                 0.422358
# RGS021425_ph4                    0.624072                 0.430305
# RGS021425_ph5                    0.604746                 0.433075
# RGS021425_ph6                    0.631284                 0.434659
# RGS021425_ph7                    0.592118                 0.420755
# RGS021425_ph8                    0.580734                 0.429094
# RGS021425_ph9                    0.572573                 0.442097
# RGS021425_ph10                   0.584947                 0.431557
# RGS021425_ph11                   0.556394                 0.423030
# RGS021425_ph12                   0.584093                 0.422735
# RGS021425_ph13                   0.608961                 0.439381
# RGS021425_ph14                   0.604441                 0.441174
# RGS021425_ph15                   0.624934                 0.428965
# RGS021425_ph1                    0.623158                 0.425253
# RGS021425_ph2                    0.605730                 0.431908
# RGS021425_ph3                    0.560925                 0.421570
# RGS021425_ph4                    0.623940                 0.430203
# RGS021425_ph5                    0.603819                 0.432960
# RGS021425_ph6                    0.641986                 0.444167
# RGS021425_ph7                    0.594438                 0.421294
# RGS021425_ph8                    0.561138                 0.436979
# RGS021425_ph9                    0.572612                 0.441747
# RGS021425_ph10                   0.584985                 0.431782
# RGS021425_ph11                   0.555852                 0.423172
# RGS021425_ph12                   0.582096                 0.421989
# RGS021425_ph13                   0.608935                 0.439194
# RGS021425_ph14                   0.604313                 0.441149
# RGS021425_ph15                   0.624958                 0.429438
#
#                 original_shape_LeastAxisLength  \
# case_id
# RGS021425_ph1                        10.201977
# RGS021425_ph2                        10.193548
# RGS021425_ph3                        10.189014
# RGS021425_ph4                        10.196272
# RGS021425_ph5                        10.186868
# RGS021425_ph6                        10.193462
# RGS021425_ph8                        10.187914
# RGS021425_ph9                        10.188503
# RGS021425_ph10                       10.327033
# RGS021425_ph11                       10.189193
# RGS021425_ph12                       10.190546
# RGS021425_ph13                       10.184350
# RGS021425_ph14                       10.188413
# RGS021425_ph15                       10.194288
# RGS021425_ph1                        10.202086
# RGS021425_ph2                        10.192579
# RGS021425_ph3                        10.186404
# RGS021425_ph4                        10.196251
# RGS021425_ph5                        10.185827
# RGS021425_ph6                        10.197483
# RGS021425_ph7                        10.190403
# RGS021425_ph8                        10.191719
# RGS021425_ph9                        10.182132
# RGS021425_ph10                       10.326681
# RGS021425_ph11                       10.179657
# RGS021425_ph12                       10.186591
# RGS021425_ph13                       10.187348
# RGS021425_ph14                       10.187986
# RGS021425_ph15                       10.188900
# RGS021425_ph1                        10.193571
# RGS021425_ph2                        10.198579
# RGS021425_ph3                        10.191094
# RGS021425_ph4                        10.193493
# RGS021425_ph5                        10.188650
# RGS021425_ph6                        10.190484
# RGS021425_ph7                        10.189514
# RGS021425_ph8                        10.176726
# RGS021425_ph9                        10.182587
# RGS021425_ph10                       10.326779
# RGS021425_ph11                       10.181249
# RGS021425_ph12                       10.192580
# RGS021425_ph13                       10.187320
# RGS021425_ph14                       10.189024
# RGS021425_ph15                       10.190960
#
#                 original_shape_MajorAxisLength  \
# case_id
# RGS021425_ph1                        24.073293
# RGS021425_ph2                        23.552518
# RGS021425_ph3                        24.150861
# RGS021425_ph4                        23.692987
# RGS021425_ph5                        23.491482
# RGS021425_ph6                        22.936216
# RGS021425_ph8                        23.830545
# RGS021425_ph9                        23.810374
# RGS021425_ph10                       23.945195
# RGS021425_ph11                       24.116448
# RGS021425_ph12                       24.126804
# RGS021425_ph13                       23.179378
# RGS021425_ph14                       23.133184
# RGS021425_ph15                       23.789541
# RGS021425_ph1                        24.001807
# RGS021425_ph2                        23.591308
# RGS021425_ph3                        24.117928
# RGS021425_ph4                        23.695405
# RGS021425_ph5                        23.519767
# RGS021425_ph6                        23.460859
# RGS021425_ph7                        24.219343
# RGS021425_ph8                        23.751733
# RGS021425_ph9                        23.031464
# RGS021425_ph10                       23.928904
# RGS021425_ph11                       24.063667
# RGS021425_ph12                       24.096889
# RGS021425_ph13                       23.185673
# RGS021425_ph14                       23.092907
# RGS021425_ph15                       23.752285
# RGS021425_ph1                        23.970627
# RGS021425_ph2                        23.612862
# RGS021425_ph3                        24.174146
# RGS021425_ph4                        23.694607
# RGS021425_ph5                        23.532527
# RGS021425_ph6                        22.942897
# RGS021425_ph7                        24.186248
# RGS021425_ph8                        23.288799
# RGS021425_ph9                        23.050705
# RGS021425_ph10                       23.916634
# RGS021425_ph11                       24.059357
# RGS021425_ph12                       24.153650
# RGS021425_ph13                       23.195504
# RGS021425_ph14                       23.096559
# RGS021425_ph15                       23.730933
#
#                 original_shape_Maximum2DDiameterColumn  \
# case_id
# RGS021425_ph1                                23.538532
# RGS021425_ph2                                22.962265
# RGS021425_ph3                                23.192469
# RGS021425_ph4                                22.962265
# RGS021425_ph5                                22.962265
# RGS021425_ph6                                22.847319
# RGS021425_ph8                                23.769729
# RGS021425_ph9                                23.192469
# RGS021425_ph10                               23.307724
# RGS021425_ph11                               23.077316
# RGS021425_ph12                               23.077316
# RGS021425_ph13                               22.617747
# RGS021425_ph14                               22.847319
# RGS021425_ph15                               23.192469
# RGS021425_ph1                                23.538532
# RGS021425_ph2                                22.962265
# RGS021425_ph3                                22.962265
# RGS021425_ph4                                22.732480
# RGS021425_ph5                                23.423079
# RGS021425_ph6                                23.077316
# RGS021425_ph7                                23.538532
# RGS021425_ph8                                23.423079
# RGS021425_ph9                                22.503125
# RGS021425_ph10                               23.372326
# RGS021425_ph11                               22.847319
# RGS021425_ph12                               22.962265
# RGS021425_ph13                               22.503125
# RGS021425_ph14                               23.077316
# RGS021425_ph15                               22.847319
# RGS021425_ph1                                23.307724
# RGS021425_ph2                                23.538532
# RGS021425_ph3                                23.192469
# RGS021425_ph4                                22.732480
# RGS021425_ph5                                23.423079
# RGS021425_ph6                                22.847319
# RGS021425_ph7                                23.654083
# RGS021425_ph8                                23.654083
# RGS021425_ph9                                22.732480
# RGS021425_ph10                               23.485368
# RGS021425_ph11                               22.732480
# RGS021425_ph12                               23.307724
# RGS021425_ph13                               22.617747
# RGS021425_ph14                               23.077316
# RGS021425_ph15                               22.962265
#
#                 original_shape_Maximum2DDiameterRow  \
# case_id
# RGS021425_ph1                             15.811388
# RGS021425_ph2                             15.402922
# RGS021425_ph3                             14.603082
# RGS021425_ph4                             15.606489
# RGS021425_ph5                             15.504536
# RGS021425_ph6                             15.811388
# RGS021425_ph8                             14.900189
# RGS021425_ph9                             14.800760
# RGS021425_ph10                            15.620499
# RGS021425_ph11                            14.603082
# RGS021425_ph12                            14.900189
# RGS021425_ph13                            15.000000
# RGS021425_ph14                            15.100186
# RGS021425_ph15                            15.606489
# RGS021425_ph1                             15.811388
# RGS021425_ph2                             15.301654
# RGS021425_ph3                             14.603082
# RGS021425_ph4                             15.606489
# RGS021425_ph5                             15.402922
# RGS021425_ph6                             15.708775
# RGS021425_ph7                             15.301654
# RGS021425_ph8                             14.900189
# RGS021425_ph9                             14.701722
# RGS021425_ph10                            15.524678
# RGS021425_ph11                            14.603082
# RGS021425_ph12                            14.900189
# RGS021425_ph13                            15.100186
# RGS021425_ph14                            15.100186
# RGS021425_ph15                            15.504536
# RGS021425_ph1                             15.708775
# RGS021425_ph2                             15.606489
# RGS021425_ph3                             14.701722
# RGS021425_ph4                             15.811388
# RGS021425_ph5                             15.402922
# RGS021425_ph6                             15.811388
# RGS021425_ph7                             15.402922
# RGS021425_ph8                             14.701722
# RGS021425_ph9                             14.701722
# RGS021425_ph10                            15.524678
# RGS021425_ph11                            14.603082
# RGS021425_ph12                            15.000000
# RGS021425_ph13                            15.100186
# RGS021425_ph14                            15.100186
# RGS021425_ph15                            15.606489
#
#                 original_shape_Maximum2DDiameterSlice  \
# case_id
# RGS021425_ph1                               24.313705
# RGS021425_ph2                               23.493683
# RGS021425_ph3                               23.434083
# RGS021425_ph4                               24.221955
# RGS021425_ph5                               23.491022
# RGS021425_ph6                               23.152349
# RGS021425_ph8                               23.863217
# RGS021425_ph9                               23.362965
# RGS021425_ph10                              24.000651
# RGS021425_ph11                              23.691045
# RGS021425_ph12                              23.651771
# RGS021425_ph13                              23.036995
# RGS021425_ph14                              23.104383
# RGS021425_ph15                              24.164152
# RGS021425_ph1                               24.162212
# RGS021425_ph2                               23.412070
# RGS021425_ph3                               23.412070
# RGS021425_ph4                               24.164152
# RGS021425_ph5                               23.423412
# RGS021425_ph6                               23.614416
# RGS021425_ph7                               24.136655
# RGS021425_ph8                               24.211632
# RGS021425_ph9                               22.922764
# RGS021425_ph10                              23.818323
# RGS021425_ph11                              23.691045
# RGS021425_ph12                              23.702584
# RGS021425_ph13                              23.100663
# RGS021425_ph14                              23.147624
# RGS021425_ph15                              24.131476
# RGS021425_ph1                               24.162212
# RGS021425_ph2                               23.329836
# RGS021425_ph3                               23.436083
# RGS021425_ph4                               24.168678
# RGS021425_ph5                               23.595882
# RGS021425_ph6                               23.258399
# RGS021425_ph7                               24.096810
# RGS021425_ph8                               23.442083
# RGS021425_ph9                               22.916288
# RGS021425_ph10                              23.823570
# RGS021425_ph11                              23.680820
# RGS021425_ph12                              23.835701
# RGS021425_ph13                              23.039708
# RGS021425_ph14                              23.147624
# RGS021425_ph15                              24.167708
#
#                 original_shape_Maximum3DDiameter  original_shape_MeshVolume  \
# case_id
# RGS021425_ph1                          25.320446                2429.455729
# RGS021425_ph2                          24.369871                2294.208333
# RGS021425_ph3                          24.389098                2218.093099
# RGS021425_ph4                          25.125311                2374.164062
# RGS021425_ph5                          24.377243                2244.026693
# RGS021425_ph6                          24.162212                2302.315755
# RGS021425_ph8                          24.984057                2228.785156
# RGS021425_ph9                          24.487242                2184.125651
# RGS021425_ph10                         24.802344                2277.645182
# RGS021425_ph11                         24.653854                2167.353516
# RGS021425_ph12                         24.556058                2301.344401
# RGS021425_ph13                         24.016921                2219.442057
# RGS021425_ph14                         24.079621                2183.455078
# RGS021425_ph15                         25.040280                2377.070312
# RGS021425_ph1                          25.250000                2423.761068
# RGS021425_ph2                          24.345495                2296.106771
# RGS021425_ph3                          24.345495                2213.023438
# RGS021425_ph4                          25.046207                2374.826823
# RGS021425_ph5                          24.365062                2249.306641
# RGS021425_ph6                          24.562420                2371.593099
# RGS021425_ph7                          25.052757                2335.246094
# RGS021425_ph8                          25.311188                2219.470052
# RGS021425_ph9                          23.914235                2068.231771
# RGS021425_ph10                         24.779654                2276.718750
# RGS021425_ph11                         24.653854                2163.374349
# RGS021425_ph12                         24.571961                2302.109375
# RGS021425_ph13                         24.105562                2219.462891
# RGS021425_ph14                         24.105562                2180.917318
# RGS021425_ph15                         25.010623                2376.131510
# RGS021425_ph1                          25.047767                2422.430990
# RGS021425_ph2                          24.313705                2296.557943
# RGS021425_ph3                          24.299241                2218.377604
# RGS021425_ph4                          25.025300                2373.587240
# RGS021425_ph5                          24.625000                2246.713542
# RGS021425_ph6                          24.158979                2302.070312
# RGS021425_ph7                          24.917677                2337.373698
# RGS021425_ph8                          24.202918                2051.345052
# RGS021425_ph9                          23.943945                2070.235677
# RGS021425_ph10                         24.732633                2275.619792
# RGS021425_ph11                         24.652903                2160.868490
# RGS021425_ph12                         24.890071                2304.439453
# RGS021425_ph13                         24.055275                2220.064453
# RGS021425_ph14                         24.165122                2180.867188
# RGS021425_ph15                         25.013122                2371.323568
#
#                 original_shape_MinorAxisLength  ...  \
# case_id                                         ...
# RGS021425_ph1                        14.932634  ...
# RGS021425_ph2                        14.314686  ...
# RGS021425_ph3                        13.568701  ...
# RGS021425_ph4                        14.787376  ...
# RGS021425_ph5                        14.203000  ...
# RGS021425_ph6                        14.733837  ...
# RGS021425_ph8                        13.850069  ...
# RGS021425_ph9                        13.588403  ...
# RGS021425_ph10                       13.996956  ...
# RGS021425_ph11                       13.399384  ...
# RGS021425_ph12                       14.056675  ...
# RGS021425_ph13                       14.125181  ...
# RGS021425_ph14                       13.963822  ...
# RGS021425_ph15                       14.841523  ...
# RGS021425_ph1                        14.932128  ...
# RGS021425_ph2                        14.308073  ...
# RGS021425_ph3                        13.563000  ...
# RGS021425_ph4                        14.787633  ...
# RGS021425_ph5                        14.223489  ...
# RGS021425_ph6                        14.810475  ...
# RGS021425_ph7                        14.340705  ...
# RGS021425_ph8                        13.793443  ...
# RGS021425_ph9                        13.187184  ...
# RGS021425_ph10                       13.997132  ...
# RGS021425_ph11                       13.388886  ...
# RGS021425_ph12                       14.074834  ...
# RGS021425_ph13                       14.119175  ...
# RGS021425_ph14                       13.958295  ...
# RGS021425_ph15                       14.843614  ...
# RGS021425_ph1                        14.937494  ...
# RGS021425_ph2                        14.303028  ...
# RGS021425_ph3                        13.559883  ...
# RGS021425_ph4                        14.784009  ...
# RGS021425_ph5                        14.209389  ...
# RGS021425_ph6                        14.729016  ...
# RGS021425_ph7                        14.377219  ...
# RGS021425_ph8                        13.068240  ...
# RGS021425_ph9                        13.199118  ...
# RGS021425_ph10                       13.990863  ...
# RGS021425_ph11                       13.373434  ...
# RGS021425_ph12                       14.059734  ...
# RGS021425_ph13                       14.124545  ...
# RGS021425_ph14                       13.957547  ...
# RGS021425_ph15                       14.830831  ...
#
#                 original_glszm_ZoneVariance  original_ngtdm_Busyness  \
# case_id
# RGS021425_ph1                      0.876579                 0.412558
# RGS021425_ph2                      0.583086                 0.354572
# RGS021425_ph3                      0.578929                 0.326025
# RGS021425_ph4                      0.616732                 0.360069
# RGS021425_ph5                      0.614838                 0.377509
# RGS021425_ph6                      0.641956                 0.526410
# RGS021425_ph8                      0.503720                 0.262337
# RGS021425_ph9                      0.314523                 0.200376
# RGS021425_ph10                     0.433468                 0.217017
# RGS021425_ph11                     0.356272                 0.158747
# RGS021425_ph12                     0.492929                 0.311485
# RGS021425_ph13                     0.370314                 0.248927
# RGS021425_ph14                     0.318531                 0.189398
# RGS021425_ph15                     0.442709                 0.302882
# RGS021425_ph1                      1.319262                 0.482063
# RGS021425_ph2                      0.595847                 0.373515
# RGS021425_ph3                      0.478731                 0.281070
# RGS021425_ph4                      0.707868                 0.301327
# RGS021425_ph5                      0.589253                 0.327229
# RGS021425_ph6                      0.699462                 0.514754
# RGS021425_ph7                      0.747033                 0.378132
# RGS021425_ph8                      0.503964                 0.254286
# RGS021425_ph9                      0.445474                 0.231005
# RGS021425_ph10                     0.442047                 0.226345
# RGS021425_ph11                     0.375173                 0.164714
# RGS021425_ph12                     0.500797                 0.313797
# RGS021425_ph13                     0.368453                 0.199730
# RGS021425_ph14                     0.322330                 0.168226
# RGS021425_ph15                     0.432412                 0.283575
# RGS021425_ph1                      0.775667                 0.430999
# RGS021425_ph2                      0.714412                 0.440795
# RGS021425_ph3                      0.499627                 0.321554
# RGS021425_ph4                      0.739893                 0.369251
# RGS021425_ph5                      0.667827                 0.339173
# RGS021425_ph6                      0.610051                 0.529522
# RGS021425_ph7                      0.788611                 0.370294
# RGS021425_ph8                      0.478196                 0.202433
# RGS021425_ph9                      0.446816                 0.224641
# RGS021425_ph10                     0.447649                 0.213979
# RGS021425_ph11                     0.395541                 0.153748
# RGS021425_ph12                     0.558781                 0.331876
# RGS021425_ph13                     0.377917                 0.230262
# RGS021425_ph14                     0.352433                 0.217263
# RGS021425_ph15                     0.470317                 0.302592
#
#                 original_ngtdm_Coarseness  original_ngtdm_Complexity  \
# case_id
# RGS021425_ph1                    0.000052               1.992684e+06
# RGS021425_ph2                    0.000052               2.439394e+06
# RGS021425_ph3                    0.000059               2.450646e+06
# RGS021425_ph4                    0.000051               2.179141e+06
# RGS021425_ph5                    0.000052               2.380445e+06
# RGS021425_ph6                    0.000048               2.100131e+06
# RGS021425_ph8                    0.000050               4.441074e+06
# RGS021425_ph9                    0.000048               5.897086e+06
# RGS021425_ph10                   0.000051               4.548945e+06
# RGS021425_ph11                   0.000058               5.563444e+06
# RGS021425_ph12                   0.000048               4.323373e+06
# RGS021425_ph13                   0.000055               4.394475e+06
# RGS021425_ph14                   0.000061               4.602085e+06
# RGS021425_ph15                   0.000049               4.453504e+06
# RGS021425_ph1                    0.000050               1.635354e+06
# RGS021425_ph2                    0.000052               2.371905e+06
# RGS021425_ph3                    0.000060               2.470030e+06
# RGS021425_ph4                    0.000052               2.259675e+06
# RGS021425_ph5                    0.000053               2.373546e+06
# RGS021425_ph6                    0.000046               2.025649e+06
# RGS021425_ph7                    0.000054               2.168923e+06
# RGS021425_ph8                    0.000050               4.493795e+06
# RGS021425_ph9                    0.000056               4.264476e+06
# RGS021425_ph10                   0.000052               4.251984e+06
# RGS021425_ph11                   0.000059               5.566687e+06
# RGS021425_ph12                   0.000048               4.460727e+06
# RGS021425_ph13                   0.000058               4.363091e+06
# RGS021425_ph14                   0.000060               4.714200e+06
# RGS021425_ph15                   0.000048               4.887947e+06
# RGS021425_ph1                    0.000050               2.141600e+06
# RGS021425_ph2                    0.000051               1.878294e+06
# RGS021425_ph3                    0.000058               2.572000e+06
# RGS021425_ph4                    0.000050               2.350240e+06
# RGS021425_ph5                    0.000053               2.436088e+06
# RGS021425_ph6                    0.000047               2.119319e+06
# RGS021425_ph7                    0.000054               2.249792e+06
# RGS021425_ph8                    0.000055               4.531510e+06
# RGS021425_ph9                    0.000057               4.502755e+06
# RGS021425_ph10                   0.000051               4.537112e+06
# RGS021425_ph11                   0.000058               5.657428e+06
# RGS021425_ph12                   0.000048               4.225481e+06
# RGS021425_ph13                   0.000056               4.544727e+06
# RGS021425_ph14                   0.000057               4.898610e+06
# RGS021425_ph15                   0.000048               4.671030e+06
#
#                 original_ngtdm_Contrast  original_ngtdm_Strength  \
# case_id
# RGS021425_ph1                  2.115155                 7.503518
# RGS021425_ph2                  1.910797                 8.150953
# RGS021425_ph3                  2.093739                 8.481718
# RGS021425_ph4                  2.368433                 6.833168
# RGS021425_ph5                  2.159224                 8.271740
# RGS021425_ph6                  1.702097                 7.424504
# RGS021425_ph8                  1.807442                20.299846
# RGS021425_ph9                  2.820266                14.753288
# RGS021425_ph10                 2.747273                15.129735
# RGS021425_ph11                 2.325237                20.471221
# RGS021425_ph12                 2.075438                15.852043
# RGS021425_ph13                 2.699531                13.931957
# RGS021425_ph14                 2.848170                15.373470
# RGS021425_ph15                 2.037854                14.475002
# RGS021425_ph1                  1.883527                 6.741935
# RGS021425_ph2                  1.891854                 8.105515
# RGS021425_ph3                  2.150531                 8.429106
# RGS021425_ph4                  2.322642                 7.197670
# RGS021425_ph5                  1.968554                 8.852764
# RGS021425_ph6                  1.733683                 6.751669
# RGS021425_ph7                  1.968303                 8.356280
# RGS021425_ph8                  1.935738                19.365891
# RGS021425_ph9                  2.463054                17.572144
# RGS021425_ph10                 2.744987                14.531393
# RGS021425_ph11                 2.331395                20.645529
# RGS021425_ph12                 2.035746                16.809585
# RGS021425_ph13                 2.621690                14.508217
# RGS021425_ph14                 2.791434                15.579784
# RGS021425_ph15                 2.039237                15.572653
# RGS021425_ph1                  2.071827                 7.765940
# RGS021425_ph2                  1.812772                 6.947553
# RGS021425_ph3                  2.119998                 8.651433
# RGS021425_ph4                  2.388712                 7.419369
# RGS021425_ph5                  2.132923                 8.800893
# RGS021425_ph6                  1.994227                 6.372734
# RGS021425_ph7                  1.939991                 8.848627
# RGS021425_ph8                  2.202111                19.207765
# RGS021425_ph9                  2.473812                18.645417
# RGS021425_ph10                 2.664115                15.357144
# RGS021425_ph11                 2.405121                19.411418
# RGS021425_ph12                 2.148581                15.446725
# RGS021425_ph13                 2.669822                14.910184
# RGS021425_ph14                 2.749438                15.440206
# RGS021425_ph15                 2.159375                15.209845
#
#                        mask_name  timepoint  modality  augmentation
# case_id
# RGS021425_ph1   Snickers_Ricardo         d1        T2         aug_0
# RGS021425_ph2   Snickers_Ricardo         d1        T2         aug_0
# RGS021425_ph3   Snickers_Ricardo         d1        T2         aug_0
# RGS021425_ph4   Snickers_Ricardo         d1        T2         aug_0
# RGS021425_ph5   Snickers_Ricardo         d1        T2         aug_0
# RGS021425_ph6   Snickers_Ricardo         d1        T2         aug_0
# RGS021425_ph8   Snickers_Ricardo         d1        T2         aug_0
# RGS021425_ph9   Snickers_Ricardo         d1        T2         aug_0
# RGS021425_ph10  Snickers_Ricardo         d1        T2         aug_0
# RGS021425_ph11  Snickers_Ricardo         d1        T2         aug_0
# RGS021425_ph12  Snickers_Ricardo         d1        T2         aug_0
# RGS021425_ph13  Snickers_Ricardo         d1        T2         aug_0
# RGS021425_ph14  Snickers_Ricardo         d1        T2         aug_0
# RGS021425_ph15  Snickers_Ricardo         d1        T2         aug_0
# RGS021425_ph1   Snickers_Ricardo         d5        T2         aug_0
# RGS021425_ph2   Snickers_Ricardo         d5        T2         aug_0
# RGS021425_ph3   Snickers_Ricardo         d5        T2         aug_0
# RGS021425_ph4   Snickers_Ricardo         d5        T2         aug_0
# RGS021425_ph5   Snickers_Ricardo         d5        T2         aug_0
# RGS021425_ph6   Snickers_Ricardo         d5        T2         aug_0
# RGS021425_ph7   Snickers_Ricardo         d5        T2         aug_0
# RGS021425_ph8   Snickers_Ricardo         d5        T2         aug_0
# RGS021425_ph9   Snickers_Ricardo         d5        T2         aug_0
# RGS021425_ph10  Snickers_Ricardo         d5        T2         aug_0
# RGS021425_ph11  Snickers_Ricardo         d5        T2         aug_0
# RGS021425_ph12  Snickers_Ricardo         d5        T2         aug_0
# RGS021425_ph13  Snickers_Ricardo         d5        T2         aug_0
# RGS021425_ph14  Snickers_Ricardo         d5        T2         aug_0
# RGS021425_ph15  Snickers_Ricardo         d5        T2         aug_0
# RGS021425_ph1   Snickers_Ricardo         d8        T2         aug_0
# RGS021425_ph2   Snickers_Ricardo         d8        T2         aug_0
# RGS021425_ph3   Snickers_Ricardo         d8        T2         aug_0
# RGS021425_ph4   Snickers_Ricardo         d8        T2         aug_0
# RGS021425_ph5   Snickers_Ricardo         d8        T2         aug_0
# RGS021425_ph6   Snickers_Ricardo         d8        T2         aug_0
# RGS021425_ph7   Snickers_Ricardo         d8        T2         aug_0
# RGS021425_ph8   Snickers_Ricardo         d8        T2         aug_0
# RGS021425_ph9   Snickers_Ricardo         d8        T2         aug_0
# RGS021425_ph10  Snickers_Ricardo         d8        T2         aug_0
# RGS021425_ph11  Snickers_Ricardo         d8        T2         aug_0
# RGS021425_ph12  Snickers_Ricardo         d8        T2         aug_0
# RGS021425_ph13  Snickers_Ricardo         d8        T2         aug_0
# RGS021425_ph14  Snickers_Ricardo         d8        T2         aug_0
# RGS021425_ph15  Snickers_Ricardo         d8        T2         aug_0
#
# [44 rows x 111 columns]

# %%
# Calculates coefficient of variation for each case and feature across multiple timepoints
# Note: Timepoint column must be present in df
cov = get_longitudinal_cov(
    df,
    mask_name='Snickers_Ricardo',
    modality='T2'
)
cov
# Out:
#                 original_shape_Elongation  original_shape_Flatness  \
# case_id
# RGS021425_ph1                    0.232845                 0.187092
# RGS021425_ph10                   0.042012                 0.058552
# RGS021425_ph11                   0.072100                 0.083805
# RGS021425_ph12                   0.177774                 0.088264
# RGS021425_ph13                   0.041554                 0.024003
# RGS021425_ph14                   0.072406                 0.096583
# RGS021425_ph15                   0.099700                 0.107022
# RGS021425_ph2                    0.170452                 0.111099
# RGS021425_ph3                    0.129334                 0.093946
# RGS021425_ph4                    0.015250                 0.017474
# RGS021425_ph5                    0.082542                 0.084097
# RGS021425_ph6                    0.986027                 1.261825
# RGS021425_ph7                    0.276502                 0.090524
# RGS021425_ph8                    1.993095                 1.175889
# RGS021425_ph9                    0.191813                 1.851671
#
#                 original_shape_LeastAxisLength  \
# case_id
# RGS021425_ph1                         0.047897
# RGS021425_ph10                        0.001761
# RGS021425_ph11                        0.050162
# RGS021425_ph12                        0.029889
# RGS021425_ph13                        0.016915
# RGS021425_ph14                        0.005121
# RGS021425_ph15                        0.026680
# RGS021425_ph2                         0.031593
# RGS021425_ph3                         0.023063
# RGS021425_ph4                         0.015679
# RGS021425_ph5                         0.014014
# RGS021425_ph6                         0.034456
# RGS021425_ph7                         0.006167
# RGS021425_ph8                         0.076519
# RGS021425_ph9                         0.034897
#
#                 original_shape_MajorAxisLength  \
# case_id
# RGS021425_ph1                         0.219173
# RGS021425_ph10                        0.059872
# RGS021425_ph11                        0.132021
# RGS021425_ph12                        0.117693
# RGS021425_ph13                        0.035052
# RGS021425_ph14                        0.096396
# RGS021425_ph15                        0.124851
# RGS021425_ph2                         0.129654
# RGS021425_ph3                         0.116973
# RGS021425_ph4                         0.005200
# RGS021425_ph5                         0.089330
# RGS021425_ph6                         1.302247
# RGS021425_ph7                         0.096690
# RGS021425_ph8                         1.238971
# RGS021425_ph9                         1.906871
#
#                 original_shape_Maximum2DDiameterColumn  \
# case_id
# RGS021425_ph1                                 0.567980
# RGS021425_ph10                                0.384445
# RGS021425_ph11                                0.767263
# RGS021425_ph12                                0.760997
# RGS021425_ph13                                0.293086
# RGS021425_ph14                                0.577325
# RGS021425_ph15                                0.764121
# RGS021425_ph2                                 1.436913
# RGS021425_ph3                                 0.574969
# RGS021425_ph4                                 0.581641
# RGS021425_ph5                                 1.143347
# RGS021425_ph6                                 0.579256
# RGS021425_ph7                                 0.346268
# RGS021425_ph8                                 0.747365
# RGS021425_ph9                                 1.539033
#
#                 original_shape_Maximum2DDiameterRow  \
# case_id
# RGS021425_ph1                          3.755016e-01
# RGS021425_ph10                         3.556205e-01
# RGS021425_ph11                         1.489811e-14
# RGS021425_ph12                         3.858855e-01
# RGS021425_ph13                         3.839076e-01
# RGS021425_ph14                         0.000000e+00
# RGS021425_ph15                         3.779920e-01
# RGS021425_ph2                          1.005712e+00
# RGS021425_ph3                          3.891088e-01
# RGS021425_ph4                          7.547065e-01
# RGS021425_ph5                          3.800451e-01
# RGS021425_ph6                          3.755016e-01
# RGS021425_ph7                          4.664251e-01
# RGS021425_ph8                          7.724462e-01
# RGS021425_ph9                          3.880611e-01
#
#                 original_shape_Maximum2DDiameterSlice  \
# case_id
# RGS021425_ph1                                0.361233
# RGS021425_ph10                               0.434598
# RGS021425_ph11                               0.024922
# RGS021425_ph12                               0.400271
# RGS021425_ph13                               0.156126
# RGS021425_ph14                               0.107920
# RGS021425_ph15                               0.082683
# RGS021425_ph2                                0.349923
# RGS021425_ph3                                0.056876
# RGS021425_ph4                                0.132917
# RGS021425_ph5                                0.369743
# RGS021425_ph6                                1.036942
# RGS021425_ph7                                0.116827
# RGS021425_ph8                                1.616457
# RGS021425_ph9                                1.109967
#
#                 original_shape_Maximum3DDiameter  original_shape_MeshVolume  \
# case_id
# RGS021425_ph1                           0.561563                   0.153863
# RGS021425_ph10                          0.143536                   0.044535
# RGS021425_ph11                          0.002226                   0.151132
# RGS021425_ph12                          0.763676                   0.070013
# RGS021425_ph13                          0.184770                   0.015925
# RGS021425_ph14                          0.181776                   0.067829
# RGS021425_ph15                          0.065739                   0.129812
# RGS021425_ph2                           0.115699                   0.054316
# RGS021425_ph3                           0.184579                   0.135911
# RGS021425_ph4                           0.210456                   0.026126
# RGS021425_ph5                           0.599798                   0.117512
# RGS021425_ph6                           0.954945                   1.723127
# RGS021425_ph7                           0.382290                   0.064394
# RGS021425_ph8                           2.293035                   4.609425
# RGS021425_ph9                           1.337713                   3.147781
#
#                 original_shape_MinorAxisLength  ...  \
# case_id                                         ...
# RGS021425_ph1                         0.019840  ...
# RGS021425_ph10                        0.025510  ...
# RGS021425_ph11                        0.097508  ...
# RGS021425_ph12                        0.069129  ...
# RGS021425_ph13                        0.023361  ...
# RGS021425_ph14                        0.024551  ...
# RGS021425_ph15                        0.046208  ...
# RGS021425_ph2                         0.040857  ...
# RGS021425_ph3                         0.032969  ...
# RGS021425_ph4                         0.013677  ...
# RGS021425_ph5                         0.073764  ...
# RGS021425_ph6                         0.309681  ...
# RGS021425_ph7                         0.179812  ...
# RGS021425_ph8                         3.212562  ...
# RGS021425_ph9                         1.713158  ...
#
#                 original_glszm_SmallAreaHighGrayLevelEmphasis  \
# case_id
# RGS021425_ph1                                        8.066264
# RGS021425_ph10                                       1.625181
# RGS021425_ph11                                       3.775481
# RGS021425_ph12                                       1.018045
# RGS021425_ph13                                       9.581735
# RGS021425_ph14                                       9.713846
# RGS021425_ph15                                       4.918712
# RGS021425_ph2                                       10.082758
# RGS021425_ph3                                        8.282872
# RGS021425_ph4                                       11.382781
# RGS021425_ph5                                        4.454828
# RGS021425_ph6                                        4.155931
# RGS021425_ph7                                        0.155945
# RGS021425_ph8                                       12.939430
# RGS021425_ph9                                       15.987741
#
#                 original_glszm_SmallAreaLowGrayLevelEmphasis  \
# case_id
# RGS021425_ph1                                       2.674900
# RGS021425_ph10                                      5.061475
# RGS021425_ph11                                      8.693389
# RGS021425_ph12                                     10.325365
# RGS021425_ph13                                     30.708863
# RGS021425_ph14                                     28.399232
# RGS021425_ph15                                     19.483338
# RGS021425_ph2                                      13.283194
# RGS021425_ph3                                      21.099383
# RGS021425_ph4                                      30.688601
# RGS021425_ph5                                      16.039548
# RGS021425_ph6                                      13.395470
# RGS021425_ph7                                       6.146228
# RGS021425_ph8                                      25.463451
# RGS021425_ph9                                      38.661249
#
#                 original_glszm_ZoneEntropy  original_glszm_ZonePercentage  \
# case_id
# RGS021425_ph1                     0.419174                       1.971806
# RGS021425_ph10                    0.122573                       0.311749
# RGS021425_ph11                    0.205296                       0.320060
# RGS021425_ph12                    0.190258                       0.463319
# RGS021425_ph13                    0.196729                       0.080983
# RGS021425_ph14                    0.115024                       0.339911
# RGS021425_ph15                    0.286834                       0.366329
# RGS021425_ph2                     0.453007                       1.254665
# RGS021425_ph3                     0.066891                       0.589116
# RGS021425_ph4                     0.228027                       0.489311
# RGS021425_ph5                     0.222294                       0.199235
# RGS021425_ph6                     0.171705                       0.663272
# RGS021425_ph7                     0.177206                       0.484390
# RGS021425_ph8                     0.462451                       0.463823
# RGS021425_ph9                     0.335736                       1.959636
#
#                 original_glszm_ZoneVariance  original_ngtdm_Busyness  \
# case_id
# RGS021425_ph1                     29.192321                 8.148479
# RGS021425_ph10                     1.619435                 2.941037
# RGS021425_ph11                     5.227887                 3.451175
# RGS021425_ph12                     6.949594                 3.499530
# RGS021425_ph13                     1.346950                10.974543
# RGS021425_ph14                     5.609936                12.834280
# RGS021425_ph15                     4.370323                 3.733499
# RGS021425_ph2                     11.474803                11.629962
# RGS021425_ph3                     10.183100                 8.000336
# RGS021425_ph4                      9.285740                10.726941
# RGS021425_ph5                      6.422666                 7.549166
# RGS021425_ph6                      6.965918                 1.486970
# RGS021425_ph7                      3.829106                 1.481000
# RGS021425_ph8                      2.989549                13.564213
# RGS021425_ph9                     18.891499                 7.391304
#
#                 original_ngtdm_Coarseness  original_ngtdm_Complexity  \
# case_id
# RGS021425_ph1                    2.097101                  13.528122
# RGS021425_ph10                   0.848544                   3.781786
# RGS021425_ph11                   0.477665                   0.953384
# RGS021425_ph12                   0.208353                   2.725066
# RGS021425_ph13                   2.250778                   2.189499
# RGS021425_ph14                   3.899194                   3.159866
# RGS021425_ph15                   1.457836                   4.650598
# RGS021425_ph2                    1.226594                  13.737748
# RGS021425_ph3                    1.478323                   2.610262
# RGS021425_ph4                    1.312962                   3.782496
# RGS021425_ph5                    1.005462                   1.430753
# RGS021425_ph6                    2.299202                   2.376906
# RGS021425_ph7                    0.055543                   2.588218
# RGS021425_ph8                    5.777348                   1.011964
# RGS021425_ph9                    9.487007                  18.041501
#
#                 original_ngtdm_Contrast  original_ngtdm_Strength
# case_id
# RGS021425_ph1                  6.085662                 7.249333
# RGS021425_ph10                 1.742142                 2.842413
# RGS021425_ph11                 1.888331                 3.310391
# RGS021425_ph12                 2.743140                 4.364076
# RGS021425_ph13                 1.474742                 3.402702
# RGS021425_ph14                 1.771927                 0.680776
# RGS021425_ph15                 3.355940                 3.707021
# RGS021425_ph2                  2.777857                 8.818017
# RGS021425_ph3                  1.339805                 1.363610
# RGS021425_ph4                  1.434198                 4.139617
# RGS021425_ph5                  4.951395                 3.720621
# RGS021425_ph6                  8.857596                 7.776832
# RGS021425_ph7                  1.024470                 4.047009
# RGS021425_ph8                 10.158613                 3.007394
# RGS021425_ph9                  7.858644                11.831739
#
# [15 rows x 107 columns]
